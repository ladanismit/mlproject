# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/LICENSE
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/.gitignore
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/README.md
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/requirements.txt
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_final_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_label_encoder.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/lstm_best_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/attention_label_encoder.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_best_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/bert_tokenizer.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_history.json
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/lstm_final_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/attention_history.json
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/attention_tokenizer.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/lstm_history.json
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/lstm_label_encoder.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/bilstm_attention_best_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/lstm_tokenizer.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/attention_final_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/bert_label_encoder.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_tokenizer.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/configs/config.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/artifacts/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_145217.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_122452.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_111059.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_120255.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_144226.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_122325.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260709_215923.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_143859.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_122349.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260710_220636.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_123054.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_114117.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_143422.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_122645.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260710_222018.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_113628.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260711_145152.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/notebooks/agnews-attention-training.ipynb
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/notebooks/agnews-lstm-training.ipynb
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/notebooks/agnews-rnn-training.ipynb
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/seed.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/common.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/exception.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/logger.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/file_io.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/trainer.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/train.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/callbacks.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/base_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/rnn_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/lstm_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/attention_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/custom_attention.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/bert_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/preprocessing.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/label_encoder.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/bert_tokenizer.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/data_loader.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/tokenizer_utils.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/bert_dataset.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/dataset.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/inference/predictor.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/inference/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/processed/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/raw/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/raw/train.csv
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/raw/test.csv

# %%
import shutil

shutil.copytree(
    "/kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification",
    "/kaggle/working/AG-News-Classification"
)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_58/3627903678.py in <cell line: 0>()
#       1 import shutil
#       2
# ----> 3 shutil.copytree(
#       4     "/kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification",
#       5     "/kaggle/working/AG-News-Classification"
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     496         ignored_names = ()
#     497
# --> 498     os.makedirs(dst, exist_ok=dirs_exist_ok)
#     499     errors = []
#     500     use_srcentry = copy_function is copy2 or copy_function is copy
#
# /usr/lib/python3.12/os.py in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: '/kaggle/working/AG-News-Classification'

# %%
import os

os.chdir("/kaggle/working/AG-News-Classification")
print(os.getcwd())
# Out:
# /kaggle/working/AG-News-Classification

# %%
# !ls
# Out:
# artifacts  data     logs       README.md	 saved_models
# configs    LICENSE  notebooks  requirements.txt  src

# %%
from configs.config import PROJECT_NAME

print(PROJECT_NAME)
# Out:
# AGNews-Text-Classification

# %%
from src.utils.logger import get_logger

logger = get_logger(__name__)
logger.info("Project setup successful.")
# Out:
# 2026-07-11 09:37:21,560 - __main__ - INFO - Project setup successful.

# %%
import os

print(os.path.exists("data/raw/train.csv"))
print(os.path.exists("data/raw/test.csv"))
# Out:
# True
# True

# %%
# !find /kaggle/working/AG-News-Classification -name "train.py"
# Out:
# /kaggle/working/AG-News-Classification/src/training/train.py

# %%
# !pip install "transformers<5" tf-keras
# Out:
# Requirement already satisfied: transformers<5 in /usr/local/lib/python3.12/dist-packages (4.57.6)
# Requirement already satisfied: tf-keras in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<5) (3.29.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<5) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<5) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<5) (4.67.3)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in /usr/local/lib/python3.12/dist-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5) (4.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (81.0.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.81.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<5) (2026.4.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.19.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)

# %%
# !python src/training/train.py --model bert
# Out:
# 2026-07-11 09:38:23,314 - training_orchestrator - INFO - ============================================================
# 2026-07-11 09:38:23,314 - training_orchestrator - INFO - STARTING MODEL TRAINING PIPELINE - MODEL: BERT
# 2026-07-11 09:38:23,314 - training_orchestrator - INFO - ============================================================
# 2026-07-11 09:38:23,314 - training_orchestrator - INFO - CLI Parameters: {'model': 'bert', 'epochs': 3, 'batch_size': 16, 'learning_rate': 0.001, 'patience': 3, 'min_delta': 0.0001, 'seed': 42}
# 2026-07-11 09:38:23,314 - src.utils.seed - INFO - Configuring environment with reproducibility seed: 42
# 2026-07-11 09:38:23,315 - src.utils.seed - INFO - Enforced TensorFlow operation determinism.
# 2026-07-11 09:38:23,315 - src.utils.seed - INFO - Reproducibility settings successfully configured.
# 2026-07-11 09:38:23,315 - training_orchestrator - INFO - Loading training and testing CSV datasets...
# 2026-07-11 09:38:23,315 - src.data.data_loader - INFO - Initializing loading of both train and test datasets.
# 2026-07-11 09:38:23,315 - src.data.data_loader - INFO - Loading training dataset from: /kaggle/working/AG-News-Classification/data/raw/train.csv
# 2026-07-11 09:38:23,315 - src.data.data_loader - INFO - File validated successfully: /kaggle/working/AG-News-Classification/data/raw/train.csv
# 2026-07-11 09:38:23,751 - src.data.data_loader - INFO - Renamed columns for standardization: {'Class Index': 'class', 'Description': 'description'}
# 2026-07-11 09:38:23,752 - src.data.data_loader - INFO - All required columns validated: ['description', 'class']
# 2026-07-11 09:38:23,759 - src.data.data_loader - INFO - Column 'description' has no missing values.
# 2026-07-11 09:38:23,759 - src.data.data_loader - INFO - Column 'class' has no missing values.
# 2026-07-11 09:38:23,858 - src.data.data_loader - INFO - No duplicate rows found in the dataset.
# 2026-07-11 09:38:23,859 - src.data.data_loader - INFO - Unique classes found: [np.int64(3), np.int64(4), np.int64(2), np.int64(1)] (Count: 4)
# 2026-07-11 09:38:23,859 - src.data.data_loader - INFO - Class distribution validation passed successfully.
# 2026-07-11 09:38:23,983 - src.data.data_loader - INFO -
# ============================================================
# DATASET SUMMARY: TRAINING DATASET
# ============================================================
# Shape: 120000 rows, 3 columns
# ------------------------------------------------------------
# Columns & Types:
#   - class: int64
#   - Title: object
#   - description: object
# ------------------------------------------------------------
# Missing Values:
#   - class: 0
#   - Title: 0
#   - description: 0
# ------------------------------------------------------------
# Duplicate Rows: 0
# ------------------------------------------------------------
# Class Distribution:
#   - Class 3 (Business): 30000 rows (25.00%)
#   - Class 4 (Sci/Tech): 30000 rows (25.00%)
#   - Class 2 (Sports): 30000 rows (25.00%)
#   - Class 1 (World): 30000 rows (25.00%)
# ============================================================
# 2026-07-11 09:38:23,983 - src.data.data_loader - INFO - Loading testing dataset from: /kaggle/working/AG-News-Classification/data/raw/test.csv
# 2026-07-11 09:38:23,984 - src.data.data_loader - INFO - File validated successfully: /kaggle/working/AG-News-Classification/data/raw/test.csv
# 2026-07-11 09:38:24,012 - src.data.data_loader - INFO - Renamed columns for standardization: {'Class Index': 'class', 'Description': 'description'}
# 2026-07-11 09:38:24,012 - src.data.data_loader - INFO - All required columns validated: ['description', 'class']
# 2026-07-11 09:38:24,013 - src.data.data_loader - INFO - Column 'description' has no missing values.
# 2026-07-11 09:38:24,013 - src.data.data_loader - INFO - Column 'class' has no missing values.
# 2026-07-11 09:38:24,019 - src.data.data_loader - INFO - No duplicate rows found in the dataset.
# 2026-07-11 09:38:24,019 - src.data.data_loader - INFO - Unique classes found: [np.int64(3), np.int64(4), np.int64(2), np.int64(1)] (Count: 4)
# 2026-07-11 09:38:24,019 - src.data.data_loader - INFO - Class distribution validation passed successfully.
# 2026-07-11 09:38:24,027 - src.data.data_loader - INFO -
# ============================================================
# DATASET SUMMARY: TESTING DATASET
# ============================================================
# Shape: 7600 rows, 3 columns
# ------------------------------------------------------------
# Columns & Types:
#   - class: int64
#   - Title: object
#   - description: object
# ------------------------------------------------------------
# Missing Values:
#   - class: 0
#   - Title: 0
#   - description: 0
# ------------------------------------------------------------
# Duplicate Rows: 0
# ------------------------------------------------------------
# Class Distribution:
#   - Class 3 (Business): 1900 rows (25.00%)
#   - Class 4 (Sci/Tech): 1900 rows (25.00%)
#   - Class 2 (Sports): 1900 rows (25.00%)
#   - Class 1 (World): 1900 rows (25.00%)
# ============================================================
# 2026-07-11 09:38:24,028 - src.data.data_loader - INFO - Both training and testing datasets loaded successfully.
# 2026-07-11 09:38:24,028 - training_orchestrator - INFO - Loaded datasets. Train shape: (120000, 3), Test shape: (7600, 3)
# 2026-07-11 09:38:24,028 - training_orchestrator - INFO - Executing text cleaning and preprocessing...
# 2026-07-11 09:38:24,028 - src.data.preprocessing - INFO - Preprocessing text column 'description' in DataFrame...
# 2026-07-11 09:38:26,990 - src.data.preprocessing - INFO - Preprocessing completed. Saved results to 'description'.
# 2026-07-11 09:38:26,993 - src.data.preprocessing - INFO - Preprocessing text column 'description' in DataFrame...
# 2026-07-11 09:38:27,201 - src.data.preprocessing - INFO - Preprocessing completed. Saved results to 'description'.
# 2026-07-11 09:38:27,201 - training_orchestrator - INFO - Initializing BERT tokenizer...
# 2026-07-11 09:38:38,028 - src.data.bert_tokenizer - INFO - Loading pretrained tokenizer for model: bert-base-uncased
# tokenizer_config.json: 100%|██████████████████| 48.0/48.0 [00:00<00:00, 347kB/s]
# config.json: 100%|█████████████████████████████| 570/570 [00:00<00:00, 4.93MB/s]
# vocab.txt: 232kB [00:00, 11.9MB/s]
# tokenizer.json: 466kB [00:00, 7.03MB/s]
# 2026-07-11 09:38:39,461 - src.data.bert_tokenizer - INFO - Pretrained tokenizer loaded successfully.
# 2026-07-11 09:38:39,461 - src.data.bert_tokenizer - INFO - Saving tokenizer artifact to: /kaggle/working/AG-News-Classification/saved_models/bert_tokenizer.pkl
# 2026-07-11 09:38:39,464 - src.utils.file_io - INFO - Pickle file saved successfully at: /kaggle/working/AG-News-Classification/saved_models/bert_tokenizer.pkl
# 2026-07-11 09:38:39,464 - training_orchestrator - INFO - BERT tokenizer saved successfully to: /kaggle/working/AG-News-Classification/saved_models/bert_tokenizer.pkl
# 2026-07-11 09:38:39,468 - src.data.bert_tokenizer - INFO - Tokenizing 120000 text sequences...
# 2026-07-11 09:38:58,195 - src.data.bert_tokenizer - INFO - Text sequence tokenization completed.
# 2026-07-11 09:38:59,069 - src.data.bert_tokenizer - INFO - Tokenizing 7600 text sequences...
# 2026-07-11 09:39:00,064 - src.data.bert_tokenizer - INFO - Text sequence tokenization completed.
# 2026-07-11 09:39:00,118 - training_orchestrator - INFO - Initializing label encoding...
# 2026-07-11 09:39:00,121 - src.data.label_encoder - INFO - Fitted CustomLabelEncoder on 4 unique classes: [1, 2, 3, 4]
# 2026-07-11 09:39:00,121 - src.data.label_encoder - INFO - Saving label encoder to: /kaggle/working/AG-News-Classification/saved_models/bert_label_encoder.pkl
# 2026-07-11 09:39:00,121 - src.utils.file_io - INFO - Pickle file saved successfully at: /kaggle/working/AG-News-Classification/saved_models/bert_label_encoder.pkl
# 2026-07-11 09:39:00,122 - training_orchestrator - INFO - Label encoder saved successfully to: /kaggle/working/AG-News-Classification/saved_models/bert_label_encoder.pkl
# 2026-07-11 09:39:00,122 - src.data.label_encoder - INFO - Encoding 120000 labels...
# 2026-07-11 09:39:00,142 - src.data.label_encoder - INFO - Encoding 7600 labels...
# 2026-07-11 09:39:00,144 - training_orchestrator - INFO - Creating optimized tf.data.Dataset pipelines...
# 2026-07-11 09:39:00,147 - src.data.bert_dataset - INFO - Initializing BERT datasets creation pipeline...
# 2026-07-11 09:39:00,147 - src.data.bert_dataset - INFO - Splitting BERT arrays with validation_split=0.2 and random_seed=42
# 2026-07-11 09:39:00,269 - src.data.bert_dataset - INFO - Split complete. Training: 96000 samples, Validation: 24000 samples.
# 2026-07-11 09:39:00,269 - src.data.bert_dataset - INFO - Creating tf.data.Dataset. Input shapes - input_ids: (96000, 128), attention_masks: (96000, 128), token_type_ids: (96000, 128)
# 2026-07-11 09:39:00,269 - src.data.bert_dataset - INFO - Adding target labels with shape: (96000,)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783762741.076966     173 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1783762741.083295     173 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 2026-07-11 09:39:01,732 - src.data.bert_dataset - INFO - Creating tf.data.Dataset. Input shapes - input_ids: (24000, 128), attention_masks: (24000, 128), token_type_ids: (24000, 128)
# 2026-07-11 09:39:01,732 - src.data.bert_dataset - INFO - Adding target labels with shape: (24000,)
# 2026-07-11 09:39:01,875 - src.data.bert_dataset - INFO - Creating tf.data.Dataset. Input shapes - input_ids: (7600, 128), attention_masks: (7600, 128), token_type_ids: (7600, 128)
# 2026-07-11 09:39:01,876 - src.data.bert_dataset - INFO - Adding target labels with shape: (7600,)
# 2026-07-11 09:39:01,909 - src.data.bert_dataset - INFO - Optimizing training dataset (shuffled, batched, prefetched)...
# 2026-07-11 09:39:03,719 - src.data.bert_dataset - INFO - Optimizing validation dataset (batched, prefetched)...
# 2026-07-11 09:39:03,722 - src.data.bert_dataset - INFO - Optimizing testing dataset (batched, prefetched)...
# 2026-07-11 09:39:03,726 - src.data.bert_dataset - INFO - BERT model datasets successfully created and optimized.
# 2026-07-11 09:39:03,726 - training_orchestrator - INFO - Loading class configuration for model type: 'bert'
# 2026-07-11 09:39:03,783 - training_orchestrator - INFO - Instantiating model class: BERTModel
# 2026-07-11 09:39:03,783 - BERTModel - INFO - Initialized BERTModel instance.
# 2026-07-11 09:39:03,783 - training_orchestrator - INFO - Building model layers...
# 2026-07-11 09:39:03,783 - BERTModel - INFO - Building BERT model architecture (model_name=bert-base-uncased)...
# pytorch_model.bin: 100%|██████████████████████| 440M/440M [00:04<00:00, 110MB/s]
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# 2026-07-11 09:39:10,465 - BERTModel - INFO - Configured top 2 encoder layers of BERT as trainable. Rest of the layers are frozen.
# 2026-07-11 09:39:15,186 - BERTModel - INFO - BERT model architecture built successfully.
# 2026-07-11 09:39:15,186 - training_orchestrator - INFO - Compiling model with learning_rate=0.001...
# 2026-07-11 09:39:15,189 - BERTModel - INFO - Compiling BERT model (optimizer=<tf_keras.src.optimizers.adam.Adam object at 0x7d968248b050>, loss=sparse_categorical_crossentropy, metrics=['accuracy'])
# 2026-07-11 09:39:15,200 - BERTModel - INFO - BERT model compiled successfully.
# Model: "BERTModel"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  attention_mask (InputLayer  [(None, 128)]                0         []
#  )
#
#  input_ids (InputLayer)      [(None, 128)]                0         []
#
#  token_type_ids (InputLayer  [(None, 128)]                0         []
#  )
#
#  tf_bert_model (TFBertModel  TFBaseModelOutputWithPooli   1094822   ['attention_mask[0][0]',
#  )                           ngAndCrossAttentions(last_   40         'input_ids[0][0]',
#                              hidden_state=(None, 128, 7              'token_type_ids[0][0]']
#                              68),
#                               pooler_output=(None, 768)
#                              , past_key_values=None, hi
#                              dden_states=None, attentio
#                              ns=None, cross_attentions=
#                              None)
#
#  dropout_layer (Dropout)     (None, 768)                  0         ['tf_bert_model[0][1]']
#
#  output_layer (Dense)        (None, 4)                    3076      ['dropout_layer[0][0]']
#
# ==================================================================================================
# Total params: 109485316 (417.65 MB)
# Trainable params: 14769412 (56.34 MB)
# Non-trainable params: 94715904 (361.31 MB)
# __________________________________________________________________________________________________
# 2026-07-11 09:39:15,210 - training_orchestrator - INFO - Generating training callbacks (EarlyStopping, Checkpoint)...
# 2026-07-11 09:39:15,211 - BERTModel - INFO - Generated 2 callbacks for BERT training.
# 2026-07-11 09:39:15,211 - training_orchestrator - INFO - Beginning model fitting and training process...
# Epoch 1/3
# I0000 00:00:1783762768.827221     205 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 6000/6000 [==============================] - ETA: 0s - loss: 0.5124 - accuracy: 0.8405
# Epoch 1: val_loss improved from inf to 0.37430, saving model to /kaggle/working/AG-News-Classification/saved_models/bert_best_model.h5
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training.py:3098: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native TF-Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 6000/6000 [==============================] - 1403s 231ms/step - loss: 0.5124 - accuracy: 0.8405 - val_loss: 0.3743 - val_accuracy: 0.8888
# Epoch 2/3
# 6000/6000 [==============================] - ETA: 0s - loss: 0.4376 - accuracy: 0.8616
# Epoch 2: val_loss did not improve from 0.37430
# 6000/6000 [==============================] - 1386s 231ms/step - loss: 0.4376 - accuracy: 0.8616 - val_loss: 0.5379 - val_accuracy: 0.8232
# Epoch 3/3
# 6000/6000 [==============================] - ETA: 0s - loss: 0.4345 - accuracy: 0.8586
# Epoch 3: val_loss did not improve from 0.37430
# 6000/6000 [==============================] - 1382s 230ms/step - loss: 0.4345 - accuracy: 0.8586 - val_loss: 0.4017 - val_accuracy: 0.8706
# Restoring model weights from the end of the best epoch: 1.
# 2026-07-11 10:48:47,172 - training_orchestrator - INFO - Model training process finished successfully.
# 2026-07-11 10:48:47,172 - training_orchestrator - INFO - Saving final trained model checkpoint at: /kaggle/working/AG-News-Classification/saved_models/bert_final_model.h5
# 2026-07-11 10:48:48,029 - training_orchestrator - INFO - Final model saved successfully.
# 2026-07-11 10:48:48,029 - training_orchestrator - INFO - Saving training history log to: /kaggle/working/AG-News-Classification/saved_models/bert_history.json
# 2026-07-11 10:48:48,029 - src.utils.file_io - INFO - JSON file saved successfully at: /kaggle/working/AG-News-Classification/saved_models/bert_history.json
# 2026-07-11 10:48:48,029 - training_orchestrator - INFO - Training history logged successfully.
# 2026-07-11 10:48:48,030 - training_orchestrator - INFO - ============================================================
# 2026-07-11 10:48:48,030 - training_orchestrator - INFO - TRAINING COMPLETE - BERT MODEL DEPLOYED TO SAVED_MODELS
# 2026-07-11 10:48:48,030 - training_orchestrator - INFO - ============================================================
