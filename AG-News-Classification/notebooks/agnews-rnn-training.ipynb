# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/LICENSE
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/.gitignore
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/README.md
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/requirements.txt
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/configs/config.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/artifacts/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/seed.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/common.py
# ...

# %%
import tensorflow as tf

print("TensorFlow:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow: 2.20.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import shutil

shutil.copytree(
    "/kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification",
    "/kaggle/working/AG-News-Classification"
)
# Out:
# '/kaggle/working/AG-News-Classification'

# %%
import os

os.chdir("/kaggle/working/AG-News-Classification")
print(os.getcwd())
# Out:
# /kaggle/working/AG-News-Classification

# %%
# !ls
# Out:
# artifacts  data     logs       requirements.txt  src
# configs    LICENSE  README.md  saved_models

# %%
from configs.config import PROJECT_NAME

print(PROJECT_NAME)
# Out:
# AGNews-Text-Classification

# %%
from src.utils.logger import get_logger

logger = get_logger(__name__)
logger.info("Project setup successful.")
# Out:
# 2026-07-08 17:55:12,639 - __main__ - INFO - Project setup successful.

# %%
import os

print(os.path.exists("data/raw/train.csv"))
print(os.path.exists("data/raw/test.csv"))
# Out:
# True
# True

# %%
# !find /kaggle/working/AG-News-Classification -name "train.py"
# Out:
# /kaggle/working/AG-News-Classification/src/training/train.py

# %%
# !python src/training/train.py --model rnn
# Out:
# 2026-07-08 17:58:23,596 - training_orchestrator - INFO - ============================================================
# 2026-07-08 17:58:23,597 - training_orchestrator - INFO - STARTING MODEL TRAINING PIPELINE - MODEL: RNN
# 2026-07-08 17:58:23,597 - training_orchestrator - INFO - ============================================================
# 2026-07-08 17:58:23,597 - training_orchestrator - INFO - CLI Parameters: {'model': 'rnn', 'epochs': 10, 'batch_size': 64, 'learning_rate': 0.001, 'patience': 3, 'min_delta': 0.0001, 'seed': 42}
# 2026-07-08 17:58:23,597 - src.utils.seed - INFO - Configuring environment with reproducibility seed: 42
# 2026-07-08 17:58:23,597 - src.utils.seed - INFO - Enforced TensorFlow operation determinism.
# 2026-07-08 17:58:23,597 - src.utils.seed - INFO - Reproducibility settings successfully configured.
# 2026-07-08 17:58:23,598 - training_orchestrator - INFO - Loading training and testing CSV datasets...
# ...
