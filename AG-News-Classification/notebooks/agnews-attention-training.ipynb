# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/LICENSE
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/.gitignore
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/README.md
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/requirements.txt
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_final_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_label_encoder.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/lstm_best_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_best_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_history.json
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/lstm_final_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/lstm_history.json
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/lstm_label_encoder.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/lstm_tokenizer.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_tokenizer.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/configs/config.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/artifacts/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260709_215923.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260710_220636.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260710_222018.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/notebooks/agnews-lstm-training.ipynb
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/notebooks/agnews-rnn-training.ipynb
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/seed.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/common.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/exception.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/logger.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/file_io.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/trainer.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/train.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/callbacks.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/base_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/rnn_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/lstm_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/attention_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/custom_attention.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/preprocessing.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/label_encoder.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/data_loader.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/tokenizer_utils.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/dataset.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/inference/predictor.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/inference/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/processed/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/raw/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/raw/train.csv
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/raw/test.csv

# %%
import tensorflow as tf

print("TensorFlow:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow: 2.20.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import shutil

shutil.copytree(
    "/kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification",
    "/kaggle/working/AG-News-Classification"
)
# Out:
# '/kaggle/working/AG-News-Classification'

# %%
import os

os.chdir("/kaggle/working/AG-News-Classification")
print(os.getcwd())
# Out:
# /kaggle/working/AG-News-Classification

# %%
# !ls
# Out:
# artifacts  data     logs       README.md	 saved_models
# configs    LICENSE  notebooks  requirements.txt  src

# %%
from configs.config import PROJECT_NAME

print(PROJECT_NAME)
# Out:
# AGNews-Text-Classification

# %%
from src.utils.logger import get_logger

logger = get_logger(__name__)
logger.info("Project setup successful.")
# Out:
# 2026-07-10 18:08:14,283 - __main__ - INFO - Project setup successful.

# %%
import os

print(os.path.exists("data/raw/train.csv"))
print(os.path.exists("data/raw/test.csv"))
# Out:
# True
# True

# %%
# !find /kaggle/working/AG-News-Classification -name "train.py"
# Out:
# /kaggle/working/AG-News-Classification/src/training/train.py

# %%
# !python src/training/train.py --model attention
# Out:
# 2026-07-10 18:09:11,310 - training_orchestrator - INFO - ============================================================
# 2026-07-10 18:09:11,311 - training_orchestrator - INFO - STARTING MODEL TRAINING PIPELINE - MODEL: ATTENTION
# 2026-07-10 18:09:11,311 - training_orchestrator - INFO - ============================================================
# 2026-07-10 18:09:11,311 - training_orchestrator - INFO - CLI Parameters: {'model': 'attention', 'epochs': 10, 'batch_size': 128, 'learning_rate': 0.001, 'patience': 3, 'min_delta': 0.0001, 'seed': 42}
# 2026-07-10 18:09:11,311 - src.utils.seed - INFO - Configuring environment with reproducibility seed: 42
# 2026-07-10 18:09:11,311 - src.utils.seed - INFO - Enforced TensorFlow operation determinism.
# 2026-07-10 18:09:11,311 - src.utils.seed - INFO - Reproducibility settings successfully configured.
# 2026-07-10 18:09:11,311 - training_orchestrator - INFO - Loading training and testing CSV datasets...
# 2026-07-10 18:09:11,311 - src.data.data_loader - INFO - Initializing loading of both train and test datasets.
# 2026-07-10 18:09:11,312 - src.data.data_loader - INFO - Loading training dataset from: /kaggle/working/AG-News-Classification/data/raw/train.csv
# 2026-07-10 18:09:11,312 - src.data.data_loader - INFO - File validated successfully: /kaggle/working/AG-News-Classification/data/raw/train.csv
# 2026-07-10 18:09:11,812 - src.data.data_loader - INFO - Renamed columns for standardization: {'Class Index': 'class', 'Description': 'description'}
# 2026-07-10 18:09:11,813 - src.data.data_loader - INFO - All required columns validated: ['description', 'class']
# 2026-07-10 18:09:11,820 - src.data.data_loader - INFO - Column 'description' has no missing values.
# 2026-07-10 18:09:11,820 - src.data.data_loader - INFO - Column 'class' has no missing values.
# 2026-07-10 18:09:11,929 - src.data.data_loader - INFO - No duplicate rows found in the dataset.
# 2026-07-10 18:09:11,930 - src.data.data_loader - INFO - Unique classes found: [np.int64(3), np.int64(4), np.int64(2), np.int64(1)] (Count: 4)
# 2026-07-10 18:09:11,930 - src.data.data_loader - INFO - Class distribution validation passed successfully.
# 2026-07-10 18:09:12,061 - src.data.data_loader - INFO -
# ============================================================
# DATASET SUMMARY: TRAINING DATASET
# ============================================================
# Shape: 120000 rows, 3 columns
# ------------------------------------------------------------
# Columns & Types:
#   - class: int64
#   - Title: object
#   - description: object
# ------------------------------------------------------------
# Missing Values:
#   - class: 0
#   - Title: 0
#   - description: 0
# ------------------------------------------------------------
# Duplicate Rows: 0
# ------------------------------------------------------------
# Class Distribution:
#   - Class 3 (Business): 30000 rows (25.00%)
#   - Class 4 (Sci/Tech): 30000 rows (25.00%)
#   - Class 2 (Sports): 30000 rows (25.00%)
#   - Class 1 (World): 30000 rows (25.00%)
# ============================================================
# 2026-07-10 18:09:12,061 - src.data.data_loader - INFO - Loading testing dataset from: /kaggle/working/AG-News-Classification/data/raw/test.csv
# 2026-07-10 18:09:12,061 - src.data.data_loader - INFO - File validated successfully: /kaggle/working/AG-News-Classification/data/raw/test.csv
# 2026-07-10 18:09:12,094 - src.data.data_loader - INFO - Renamed columns for standardization: {'Class Index': 'class', 'Description': 'description'}
# 2026-07-10 18:09:12,094 - src.data.data_loader - INFO - All required columns validated: ['description', 'class']
# 2026-07-10 18:09:12,095 - src.data.data_loader - INFO - Column 'description' has no missing values.
# 2026-07-10 18:09:12,095 - src.data.data_loader - INFO - Column 'class' has no missing values.
# 2026-07-10 18:09:12,101 - src.data.data_loader - INFO - No duplicate rows found in the dataset.
# 2026-07-10 18:09:12,102 - src.data.data_loader - INFO - Unique classes found: [np.int64(3), np.int64(4), np.int64(2), np.int64(1)] (Count: 4)
# 2026-07-10 18:09:12,102 - src.data.data_loader - INFO - Class distribution validation passed successfully.
# 2026-07-10 18:09:12,110 - src.data.data_loader - INFO -
# ============================================================
# DATASET SUMMARY: TESTING DATASET
# ============================================================
# Shape: 7600 rows, 3 columns
# ------------------------------------------------------------
# Columns & Types:
#   - class: int64
#   - Title: object
#   - description: object
# ------------------------------------------------------------
# Missing Values:
#   - class: 0
#   - Title: 0
#   - description: 0
# ------------------------------------------------------------
# Duplicate Rows: 0
# ------------------------------------------------------------
# Class Distribution:
#   - Class 3 (Business): 1900 rows (25.00%)
#   - Class 4 (Sci/Tech): 1900 rows (25.00%)
#   - Class 2 (Sports): 1900 rows (25.00%)
#   - Class 1 (World): 1900 rows (25.00%)
# ============================================================
# 2026-07-10 18:09:12,110 - src.data.data_loader - INFO - Both training and testing datasets loaded successfully.
# 2026-07-10 18:09:12,111 - training_orchestrator - INFO - Loaded datasets. Train shape: (120000, 3), Test shape: (7600, 3)
# 2026-07-10 18:09:12,111 - training_orchestrator - INFO - Executing text cleaning and preprocessing...
# 2026-07-10 18:09:12,111 - src.data.preprocessing - INFO - Preprocessing text column 'description' in DataFrame...
# 2026-07-10 18:09:15,426 - src.data.preprocessing - INFO - Preprocessing completed. Saved results to 'description'.
# 2026-07-10 18:09:15,429 - src.data.preprocessing - INFO - Preprocessing text column 'description' in DataFrame...
# 2026-07-10 18:09:15,639 - src.data.preprocessing - INFO - Preprocessing completed. Saved results to 'description'.
# 2026-07-10 18:09:15,640 - training_orchestrator - INFO - Initializing tokenizer training...
# 2026-07-10 18:09:15,640 - src.data.tokenizer_utils - INFO - Creating Keras Tokenizer with vocab_size=15000, oov_token='<OOV>'
# 2026-07-10 18:09:15,643 - src.data.tokenizer_utils - INFO - Fitting tokenizer on 120000 text sequences...
# 2026-07-10 18:09:18,908 - src.data.tokenizer_utils - INFO - Tokenizer fitting complete. Calculated vocab size: 92425
# 2026-07-10 18:09:18,910 - src.data.tokenizer_utils - INFO - Saving tokenizer to: /kaggle/working/AG-News-Classification/saved_models/attention_tokenizer.pkl
# 2026-07-10 18:09:18,979 - src.utils.file_io - INFO - Pickle file saved successfully at: /kaggle/working/AG-News-Classification/saved_models/attention_tokenizer.pkl
# 2026-07-10 18:09:18,979 - training_orchestrator - INFO - Fitted tokenizer saved successfully to: /kaggle/working/AG-News-Classification/saved_models/attention_tokenizer.pkl
# 2026-07-10 18:09:18,979 - training_orchestrator - INFO - Converting text fields to sequences...
# 2026-07-10 18:09:18,982 - src.data.tokenizer_utils - INFO - Converting 120000 texts to sequences...
# 2026-07-10 18:09:21,318 - src.data.tokenizer_utils - INFO - Converting 7600 texts to sequences...
# 2026-07-10 18:09:21,456 - training_orchestrator - INFO - Padding text sequences to max length of: 80
# 2026-07-10 18:09:21,920 - training_orchestrator - INFO - Initializing label encoding...
# 2026-07-10 18:09:21,923 - src.data.label_encoder - INFO - Fitted CustomLabelEncoder on 4 unique classes: [1, 2, 3, 4]
# 2026-07-10 18:09:21,923 - src.data.label_encoder - INFO - Saving label encoder to: /kaggle/working/AG-News-Classification/saved_models/attention_label_encoder.pkl
# 2026-07-10 18:09:21,923 - src.utils.file_io - INFO - Pickle file saved successfully at: /kaggle/working/AG-News-Classification/saved_models/attention_label_encoder.pkl
# 2026-07-10 18:09:21,923 - training_orchestrator - INFO - Label encoder saved successfully to: /kaggle/working/AG-News-Classification/saved_models/attention_label_encoder.pkl
# 2026-07-10 18:09:21,923 - src.data.label_encoder - INFO - Encoding 120000 labels...
# 2026-07-10 18:09:21,945 - src.data.label_encoder - INFO - Encoding 7600 labels...
# 2026-07-10 18:09:21,946 - training_orchestrator - INFO - Creating optimized tf.data.Dataset pipelines...
# 2026-07-10 18:09:21,946 - src.data.dataset - INFO - Initializing model datasets creation pipeline...
# 2026-07-10 18:09:21,947 - src.data.dataset - INFO - Splitting dataset with validation_split=0.2 and random_seed=42
# 2026-07-10 18:09:21,971 - src.data.dataset - INFO - Split complete. Training: 96000 samples, Validation: 24000 samples.
# 2026-07-10 18:09:21,971 - src.data.dataset - INFO - Creating tf.data.Dataset with features shape: (96000, 80)
# 2026-07-10 18:09:21,971 - src.data.dataset - INFO - Adding labels with shape: (96000,)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783706962.582683     144 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1783706962.585920     144 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 2026-07-10 18:09:22,645 - src.data.dataset - INFO - Creating tf.data.Dataset with features shape: (24000, 80)
# 2026-07-10 18:09:22,645 - src.data.dataset - INFO - Adding labels with shape: (24000,)
# 2026-07-10 18:09:22,657 - src.data.dataset - INFO - Creating tf.data.Dataset with features shape: (7600, 80)
# 2026-07-10 18:09:22,657 - src.data.dataset - INFO - Adding labels with shape: (7600,)
# 2026-07-10 18:09:22,663 - src.data.dataset - INFO - Optimizing training dataset (shuffled, batched, prefetched)...
# 2026-07-10 18:09:24,367 - src.data.dataset - INFO - Optimizing validation dataset (batched, prefetched)...
# 2026-07-10 18:09:24,371 - src.data.dataset - INFO - Optimizing testing dataset (batched, prefetched)...
# 2026-07-10 18:09:24,374 - src.data.dataset - INFO - Model datasets successfully created and optimized.
# 2026-07-10 18:09:24,374 - training_orchestrator - INFO - Loading class configuration for model type: 'attention'
# 2026-07-10 18:09:24,379 - training_orchestrator - INFO - Instantiating model class: AttentionModel
# 2026-07-10 18:09:24,380 - AttentionModel - INFO - Initialized AttentionModel instance.
# 2026-07-10 18:09:24,380 - training_orchestrator - INFO - Building model layers...
# 2026-07-10 18:09:24,380 - AttentionModel - INFO - Building BiLSTM + Self-Attention model architecture...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2026-07-10 18:09:25,418 - AttentionModel - INFO - BiLSTM + Self-Attention model architecture built successfully.
# 2026-07-10 18:09:25,418 - training_orchestrator - INFO - Compiling model with learning_rate=0.001...
# 2026-07-10 18:09:25,423 - AttentionModel - INFO - Compiling BiLSTM + Self-Attention model (optimizer=<keras.src.optimizers.adam.Adam object at 0x7ca0ba751940>, loss=sparse_categorical_crossentropy, metrics=['accuracy'])
# 2026-07-10 18:09:25,426 - AttentionModel - INFO - BiLSTM + Self-Attention model compiled successfully.
# Model: "BiLSTMAttentionModel"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 80)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_layer (Embedding)     │ (None, 80, 64)         │       960,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_lstm_layer        │ (None, 80, 128)        │        66,048 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ self_attention_layer            │ [(None, 128), (None,   │         8,320 │
# │ (CustomSelfAttention)           │ 80, 1)]                │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_layer (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,034,884 (3.95 MB)
#  Trainable params: 1,034,884 (3.95 MB)
#  Non-trainable params: 0 (0.00 B)
# 2026-07-10 18:09:25,433 - training_orchestrator - INFO - Generating training callbacks (EarlyStopping, Checkpoint)...
# 2026-07-10 18:09:25,433 - AttentionModel - INFO - Generated 2 callbacks for BiLSTM + Self-Attention training.
# 2026-07-10 18:09:25,433 - training_orchestrator - INFO - Beginning model fitting and training process...
# Epoch 1/10
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7078 - loss: 0.6956
# Epoch 1: val_loss improved from None to 0.28432, saving model to /kaggle/working/AG-News-Classification/saved_models/bilstm_attention_best_model.h5
# 2026-07-10 18:09:47,367 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#
# Epoch 1: finished saving model to /kaggle/working/AG-News-Classification/saved_models/bilstm_attention_best_model.h5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 22s 21ms/step - accuracy: 0.8340 - loss: 0.4471 - val_accuracy: 0.9032 - val_loss: 0.2843
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9148 - loss: 0.2501
# Epoch 2: val_loss improved from 0.28432 to 0.27212, saving model to /kaggle/working/AG-News-Classification/saved_models/bilstm_attention_best_model.h5
# 2026-07-10 18:10:02,202 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#
# Epoch 2: finished saving model to /kaggle/working/AG-News-Classification/saved_models/bilstm_attention_best_model.h5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9200 - loss: 0.2367 - val_accuracy: 0.9066 - val_loss: 0.2721
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9353 - loss: 0.1935
# Epoch 3: val_loss did not improve from 0.27212
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9374 - loss: 0.1867 - val_accuracy: 0.9008 - val_loss: 0.2955
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9470 - loss: 0.1570
# Epoch 4: val_loss did not improve from 0.27212
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9496 - loss: 0.1509 - val_accuracy: 0.8984 - val_loss: 0.3295
# Epoch 5/10
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9571 - loss: 0.1272
# Epoch 5: val_loss did not improve from 0.27212
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9591 - loss: 0.1230 - val_accuracy: 0.8941 - val_loss: 0.3717
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 2.
# 2026-07-10 18:10:46,770 - training_orchestrator - INFO - Model training process finished successfully.
# 2026-07-10 18:10:46,770 - training_orchestrator - INFO - Saving final trained model checkpoint at: /kaggle/working/AG-News-Classification/saved_models/attention_final_model.h5
# 2026-07-10 18:10:46,770 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2026-07-10 18:10:46,818 - training_orchestrator - INFO - Final model saved successfully.
# 2026-07-10 18:10:46,818 - training_orchestrator - INFO - Saving training history log to: /kaggle/working/AG-News-Classification/saved_models/attention_history.json
# 2026-07-10 18:10:46,819 - src.utils.file_io - INFO - JSON file saved successfully at: /kaggle/working/AG-News-Classification/saved_models/attention_history.json
# 2026-07-10 18:10:46,819 - training_orchestrator - INFO - Training history logged successfully.
# 2026-07-10 18:10:46,819 - training_orchestrator - INFO - ============================================================
# 2026-07-10 18:10:46,819 - training_orchestrator - INFO - TRAINING COMPLETE - ATTENTION MODEL DEPLOYED TO SAVED_MODELS
# 2026-07-10 18:10:46,819 - training_orchestrator - INFO - ============================================================
