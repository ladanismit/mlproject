# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/LICENSE
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/.gitignore
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/README.md
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/requirements.txt
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_final_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_label_encoder.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_best_model.h5
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_history.json
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/saved_models/rnn_tokenizer.pkl
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/configs/config.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/artifacts/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/project_20260709_215923.log
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/logs/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/notebooks/agnews-rnn-training.ipynb
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/seed.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/common.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/exception.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/logger.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/utils/file_io.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/trainer.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/train.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/callbacks.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/training/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/base_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/rnn_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/models/lstm_model.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/preprocessing.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/label_encoder.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/data_loader.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/tokenizer_utils.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/dataset.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/data/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/inference/predictor.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/src/inference/__init__.py
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/processed/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/raw/.gitkeep
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/raw/train.csv
# /kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification/data/raw/test.csv

# %%
import tensorflow as tf

print("TensorFlow:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow: 2.20.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import shutil

shutil.copytree(
    "/kaggle/input/datasets/smitladani/ag-news-dataset/AG-News-Classification",
    "/kaggle/working/AG-News-Classification"
)
# Out:
# '/kaggle/working/AG-News-Classification'

# %%
import os

os.chdir("/kaggle/working/AG-News-Classification")
print(os.getcwd())
# Out:
# /kaggle/working/AG-News-Classification

# %%
# !ls
# Out:
# artifacts  data     logs       README.md	 saved_models
# configs    LICENSE  notebooks  requirements.txt  src

# %%
from configs.config import PROJECT_NAME

print(PROJECT_NAME)
# Out:
# AGNews-Text-Classification

# %%
from src.utils.logger import get_logger

logger = get_logger(__name__)
logger.info("Project setup successful.")
# Out:
# 2026-07-09 17:32:39,711 - __main__ - INFO - Project setup successful.

# %%
import os

print(os.path.exists("data/raw/train.csv"))
print(os.path.exists("data/raw/test.csv"))
# Out:
# True
# True

# %%
# !find /kaggle/working/AG-News-Classification -name "train.py"
# Out:
# /kaggle/working/AG-News-Classification/src/training/train.py

# %%
# !python src/training/train.py --model lstm
# Out:
# 2026-07-09 17:33:26,804 - training_orchestrator - INFO - ============================================================
# 2026-07-09 17:33:26,804 - training_orchestrator - INFO - STARTING MODEL TRAINING PIPELINE - MODEL: LSTM
# 2026-07-09 17:33:26,804 - training_orchestrator - INFO - ============================================================
# 2026-07-09 17:33:26,804 - training_orchestrator - INFO - CLI Parameters: {'model': 'lstm', 'epochs': 10, 'batch_size': 128, 'learning_rate': 0.001, 'patience': 3, 'min_delta': 0.0001, 'seed': 42}
# 2026-07-09 17:33:26,804 - src.utils.seed - INFO - Configuring environment with reproducibility seed: 42
# 2026-07-09 17:33:26,805 - src.utils.seed - INFO - Enforced TensorFlow operation determinism.
# 2026-07-09 17:33:26,805 - src.utils.seed - INFO - Reproducibility settings successfully configured.
# 2026-07-09 17:33:26,805 - training_orchestrator - INFO - Loading training and testing CSV datasets...
# 2026-07-09 17:33:26,805 - src.data.data_loader - INFO - Initializing loading of both train and test datasets.
# 2026-07-09 17:33:26,805 - src.data.data_loader - INFO - Loading training dataset from: /kaggle/working/AG-News-Classification/data/raw/train.csv
# 2026-07-09 17:33:26,805 - src.data.data_loader - INFO - File validated successfully: /kaggle/working/AG-News-Classification/data/raw/train.csv
# 2026-07-09 17:33:27,325 - src.data.data_loader - INFO - Renamed columns for standardization: {'Class Index': 'class', 'Description': 'description'}
# 2026-07-09 17:33:27,325 - src.data.data_loader - INFO - All required columns validated: ['description', 'class']
# 2026-07-09 17:33:27,335 - src.data.data_loader - INFO - Column 'description' has no missing values.
# 2026-07-09 17:33:27,335 - src.data.data_loader - INFO - Column 'class' has no missing values.
# 2026-07-09 17:33:27,452 - src.data.data_loader - INFO - No duplicate rows found in the dataset.
# 2026-07-09 17:33:27,453 - src.data.data_loader - INFO - Unique classes found: [np.int64(3), np.int64(4), np.int64(2), np.int64(1)] (Count: 4)
# 2026-07-09 17:33:27,453 - src.data.data_loader - INFO - Class distribution validation passed successfully.
# 2026-07-09 17:33:27,594 - src.data.data_loader - INFO -
# ============================================================
# DATASET SUMMARY: TRAINING DATASET
# ============================================================
# Shape: 120000 rows, 3 columns
# ------------------------------------------------------------
# Columns & Types:
#   - class: int64
#   - Title: object
#   - description: object
# ------------------------------------------------------------
# Missing Values:
#   - class: 0
#   - Title: 0
#   - description: 0
# ------------------------------------------------------------
# Duplicate Rows: 0
# ------------------------------------------------------------
# Class Distribution:
#   - Class 3 (Business): 30000 rows (25.00%)
#   - Class 4 (Sci/Tech): 30000 rows (25.00%)
#   - Class 2 (Sports): 30000 rows (25.00%)
#   - Class 1 (World): 30000 rows (25.00%)
# ============================================================
# 2026-07-09 17:33:27,594 - src.data.data_loader - INFO - Loading testing dataset from: /kaggle/working/AG-News-Classification/data/raw/test.csv
# 2026-07-09 17:33:27,594 - src.data.data_loader - INFO - File validated successfully: /kaggle/working/AG-News-Classification/data/raw/test.csv
# 2026-07-09 17:33:27,630 - src.data.data_loader - INFO - Renamed columns for standardization: {'Class Index': 'class', 'Description': 'description'}
# 2026-07-09 17:33:27,630 - src.data.data_loader - INFO - All required columns validated: ['description', 'class']
# 2026-07-09 17:33:27,631 - src.data.data_loader - INFO - Column 'description' has no missing values.
# 2026-07-09 17:33:27,631 - src.data.data_loader - INFO - Column 'class' has no missing values.
# 2026-07-09 17:33:27,638 - src.data.data_loader - INFO - No duplicate rows found in the dataset.
# 2026-07-09 17:33:27,638 - src.data.data_loader - INFO - Unique classes found: [np.int64(3), np.int64(4), np.int64(2), np.int64(1)] (Count: 4)
# 2026-07-09 17:33:27,638 - src.data.data_loader - INFO - Class distribution validation passed successfully.
# 2026-07-09 17:33:27,646 - src.data.data_loader - INFO -
# ============================================================
# DATASET SUMMARY: TESTING DATASET
# ============================================================
# Shape: 7600 rows, 3 columns
# ------------------------------------------------------------
# Columns & Types:
#   - class: int64
#   - Title: object
#   - description: object
# ------------------------------------------------------------
# Missing Values:
#   - class: 0
#   - Title: 0
#   - description: 0
# ------------------------------------------------------------
# Duplicate Rows: 0
# ------------------------------------------------------------
# Class Distribution:
#   - Class 3 (Business): 1900 rows (25.00%)
#   - Class 4 (Sci/Tech): 1900 rows (25.00%)
#   - Class 2 (Sports): 1900 rows (25.00%)
#   - Class 1 (World): 1900 rows (25.00%)
# ============================================================
# 2026-07-09 17:33:27,646 - src.data.data_loader - INFO - Both training and testing datasets loaded successfully.
# 2026-07-09 17:33:27,647 - training_orchestrator - INFO - Loaded datasets. Train shape: (120000, 3), Test shape: (7600, 3)
# 2026-07-09 17:33:27,647 - training_orchestrator - INFO - Executing text cleaning and preprocessing...
# 2026-07-09 17:33:27,647 - src.data.preprocessing - INFO - Preprocessing text column 'description' in DataFrame...
# 2026-07-09 17:33:31,139 - src.data.preprocessing - INFO - Preprocessing completed. Saved results to 'description'.
# 2026-07-09 17:33:31,142 - src.data.preprocessing - INFO - Preprocessing text column 'description' in DataFrame...
# 2026-07-09 17:33:31,355 - src.data.preprocessing - INFO - Preprocessing completed. Saved results to 'description'.
# 2026-07-09 17:33:31,355 - training_orchestrator - INFO - Initializing tokenizer training...
# 2026-07-09 17:33:31,355 - src.data.tokenizer_utils - INFO - Creating Keras Tokenizer with vocab_size=15000, oov_token='<OOV>'
# 2026-07-09 17:33:31,359 - src.data.tokenizer_utils - INFO - Fitting tokenizer on 120000 text sequences...
# 2026-07-09 17:33:34,887 - src.data.tokenizer_utils - INFO - Tokenizer fitting complete. Calculated vocab size: 92425
# 2026-07-09 17:33:34,889 - src.data.tokenizer_utils - INFO - Saving tokenizer to: /kaggle/working/AG-News-Classification/saved_models/lstm_tokenizer.pkl
# 2026-07-09 17:33:34,975 - src.utils.file_io - INFO - Pickle file saved successfully at: /kaggle/working/AG-News-Classification/saved_models/lstm_tokenizer.pkl
# 2026-07-09 17:33:34,975 - training_orchestrator - INFO - Fitted tokenizer saved successfully to: /kaggle/working/AG-News-Classification/saved_models/lstm_tokenizer.pkl
# 2026-07-09 17:33:34,975 - training_orchestrator - INFO - Converting text fields to sequences...
# 2026-07-09 17:33:34,979 - src.data.tokenizer_utils - INFO - Converting 120000 texts to sequences...
# 2026-07-09 17:33:37,448 - src.data.tokenizer_utils - INFO - Converting 7600 texts to sequences...
# 2026-07-09 17:33:37,599 - training_orchestrator - INFO - Padding text sequences to max length of: 80
# 2026-07-09 17:33:38,096 - training_orchestrator - INFO - Initializing label encoding...
# 2026-07-09 17:33:38,099 - src.data.label_encoder - INFO - Fitted CustomLabelEncoder on 4 unique classes: [1, 2, 3, 4]
# 2026-07-09 17:33:38,100 - src.data.label_encoder - INFO - Saving label encoder to: /kaggle/working/AG-News-Classification/saved_models/lstm_label_encoder.pkl
# 2026-07-09 17:33:38,100 - src.utils.file_io - INFO - Pickle file saved successfully at: /kaggle/working/AG-News-Classification/saved_models/lstm_label_encoder.pkl
# 2026-07-09 17:33:38,100 - training_orchestrator - INFO - Label encoder saved successfully to: /kaggle/working/AG-News-Classification/saved_models/lstm_label_encoder.pkl
# 2026-07-09 17:33:38,100 - src.data.label_encoder - INFO - Encoding 120000 labels...
# 2026-07-09 17:33:38,123 - src.data.label_encoder - INFO - Encoding 7600 labels...
# 2026-07-09 17:33:38,124 - training_orchestrator - INFO - Creating optimized tf.data.Dataset pipelines...
# 2026-07-09 17:33:38,125 - src.data.dataset - INFO - Initializing model datasets creation pipeline...
# 2026-07-09 17:33:38,125 - src.data.dataset - INFO - Splitting dataset with validation_split=0.2 and random_seed=42
# 2026-07-09 17:33:38,150 - src.data.dataset - INFO - Split complete. Training: 96000 samples, Validation: 24000 samples.
# 2026-07-09 17:33:38,150 - src.data.dataset - INFO - Creating tf.data.Dataset with features shape: (96000, 80)
# 2026-07-09 17:33:38,150 - src.data.dataset - INFO - Adding labels with shape: (96000,)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783618418.787231     148 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1783618418.790241     148 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 2026-07-09 17:33:38,851 - src.data.dataset - INFO - Creating tf.data.Dataset with features shape: (24000, 80)
# 2026-07-09 17:33:38,851 - src.data.dataset - INFO - Adding labels with shape: (24000,)
# 2026-07-09 17:33:38,864 - src.data.dataset - INFO - Creating tf.data.Dataset with features shape: (7600, 80)
# 2026-07-09 17:33:38,864 - src.data.dataset - INFO - Adding labels with shape: (7600,)
# 2026-07-09 17:33:38,870 - src.data.dataset - INFO - Optimizing training dataset (shuffled, batched, prefetched)...
# 2026-07-09 17:33:40,834 - src.data.dataset - INFO - Optimizing validation dataset (batched, prefetched)...
# 2026-07-09 17:33:40,838 - src.data.dataset - INFO - Optimizing testing dataset (batched, prefetched)...
# 2026-07-09 17:33:40,841 - src.data.dataset - INFO - Model datasets successfully created and optimized.
# 2026-07-09 17:33:40,842 - training_orchestrator - INFO - Loading class configuration for model type: 'lstm'
# 2026-07-09 17:33:40,846 - training_orchestrator - INFO - Instantiating model class: LSTMModel
# 2026-07-09 17:33:40,846 - LSTMModel - INFO - Initialized LSTMModel instance.
# 2026-07-09 17:33:40,846 - training_orchestrator - INFO - Building model layers...
# 2026-07-09 17:33:40,846 - LSTMModel - INFO - Building LSTM model architecture...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2026-07-09 17:33:41,922 - LSTMModel - INFO - LSTM model architecture built successfully.
# 2026-07-09 17:33:41,922 - training_orchestrator - INFO - Compiling model with learning_rate=0.001...
# 2026-07-09 17:33:41,928 - LSTMModel - INFO - Compiling LSTM model (optimizer=<keras.src.optimizers.adam.Adam object at 0x790b11f891c0>, loss=sparse_categorical_crossentropy, metrics=['accuracy'])
# 2026-07-09 17:33:41,931 - LSTMModel - INFO - LSTM model compiled successfully.
# Model: "LSTMModel"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 80)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_layer (Embedding)     │ (None, 80, 64)         │       960,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_layer (LSTM)               │ (None, 128)            │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_layer (Dropout)         │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,059,332 (4.04 MB)
#  Trainable params: 1,059,332 (4.04 MB)
#  Non-trainable params: 0 (0.00 B)
# 2026-07-09 17:33:41,937 - training_orchestrator - INFO - Generating training callbacks (EarlyStopping, Checkpoint)...
# 2026-07-09 17:33:41,937 - LSTMModel - INFO - Generated 2 callbacks for LSTM training.
# 2026-07-09 17:33:41,937 - training_orchestrator - INFO - Beginning model fitting and training process...
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.2491 - loss: 1.3871
# Epoch 1: val_loss improved from None to 1.38658, saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 2026-07-09 17:37:23,615 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#
# Epoch 1: finished saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 222s 286ms/step - accuracy: 0.2503 - loss: 1.3869 - val_accuracy: 0.2538 - val_loss: 1.3866
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.2508 - loss: 1.3863
# Epoch 2: val_loss improved from 1.38658 to 1.22720, saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 2026-07-09 17:40:57,386 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#
# Epoch 2: finished saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 214s 285ms/step - accuracy: 0.2574 - loss: 1.3812 - val_accuracy: 0.3801 - val_loss: 1.2272
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.3912 - loss: 1.2250
# Epoch 3: val_loss improved from 1.22720 to 0.95476, saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 2026-07-09 17:44:35,137 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#
# Epoch 3: finished saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 218s 290ms/step - accuracy: 0.4201 - loss: 1.1574 - val_accuracy: 0.5172 - val_loss: 0.9548
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.5564 - loss: 0.9174
# Epoch 4: val_loss improved from 0.95476 to 0.42303, saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 2026-07-09 17:48:12,412 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#
# Epoch 4: finished saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 217s 290ms/step - accuracy: 0.6622 - loss: 0.7649 - val_accuracy: 0.8525 - val_loss: 0.4230
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.8752 - loss: 0.3900
# Epoch 5: val_loss improved from 0.42303 to 0.32864, saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 2026-07-09 17:51:47,333 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#
# Epoch 5: finished saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 215s 287ms/step - accuracy: 0.8885 - loss: 0.3538 - val_accuracy: 0.8938 - val_loss: 0.3286
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9109 - loss: 0.2906
# Epoch 6: val_loss improved from 0.32864 to 0.30302, saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 2026-07-09 17:55:21,193 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#
# Epoch 6: finished saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 214s 285ms/step - accuracy: 0.9151 - loss: 0.2788 - val_accuracy: 0.9047 - val_loss: 0.3030
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9231 - loss: 0.2512
# Epoch 7: val_loss improved from 0.30302 to 0.30253, saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 2026-07-09 17:59:02,577 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#
# Epoch 7: finished saving model to /kaggle/working/AG-News-Classification/saved_models/lstm_best_model.h5
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 221s 295ms/step - accuracy: 0.9269 - loss: 0.2417 - val_accuracy: 0.9055 - val_loss: 0.3025
# Epoch 8/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9336 - loss: 0.2221
# Epoch 8: val_loss did not improve from 0.30253
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 214s 286ms/step - accuracy: 0.9368 - loss: 0.2144 - val_accuracy: 0.9055 - val_loss: 0.3087
# Epoch 9/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 0.9417 - loss: 0.1966
# Epoch 9: val_loss did not improve from 0.30253
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 215s 287ms/step - accuracy: 0.9436 - loss: 0.1896 - val_accuracy: 0.9014 - val_loss: 0.3288
# Epoch 10/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9482 - loss: 0.1731
# Epoch 10: val_loss did not improve from 0.30253
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 213s 284ms/step - accuracy: 0.9496 - loss: 0.1692 - val_accuracy: 0.9015 - val_loss: 0.3341
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 7.
# 2026-07-09 18:09:45,064 - training_orchestrator - INFO - Model training process finished successfully.
# 2026-07-09 18:09:45,064 - training_orchestrator - INFO - Saving final trained model checkpoint at: /kaggle/working/AG-News-Classification/saved_models/lstm_final_model.h5
# 2026-07-09 18:09:45,065 - absl - WARNING - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 2026-07-09 18:09:45,104 - training_orchestrator - INFO - Final model saved successfully.
# 2026-07-09 18:09:45,104 - training_orchestrator - INFO - Saving training history log to: /kaggle/working/AG-News-Classification/saved_models/lstm_history.json
# 2026-07-09 18:09:45,104 - src.utils.file_io - INFO - JSON file saved successfully at: /kaggle/working/AG-News-Classification/saved_models/lstm_history.json
# 2026-07-09 18:09:45,104 - training_orchestrator - INFO - Training history logged successfully.
# 2026-07-09 18:09:45,105 - training_orchestrator - INFO - ============================================================
# 2026-07-09 18:09:45,105 - training_orchestrator - INFO - TRAINING COMPLETE - LSTM MODEL DEPLOYED TO SAVED_MODELS
# 2026-07-09 18:09:45,105 - training_orchestrator - INFO - ============================================================
